# %%
import pandas as pd

# %%
general = pd.read_csv('Hospital General Information.csv')

# %%
general.head(2)
# Out:
#   Provider ID                       Hospital Name             Address  \
# 0      020024  CENTRAL PENINSULA GENERAL HOSPITAL  250 HOSPITAL PLACE
# 1      021301    PROVIDENCE VALDEZ MEDICAL CENTER          PO BOX 550
#
#        City State  ZIP Code County Name  Phone Number  \
# 0  SOLDOTNA    AK     99669         NaN    9072624404
# 1    VALDEZ    AK     99686         NaN    9078352249
#
#                Hospital Type            Hospital Ownership Emergency Services
# 0       Acute Care Hospitals  Voluntary non-profit - Other                Yes
# 1  Critical Access Hospitals            Government - Local                Yes

# %%
survey = pd.read_csv('hvbp_hcahps_05_28_2015.csv')
survey
# Out:
#       Provider Number                                      Hospital Name  \
# 0               10001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 1               10005                      MARSHALL MEDICAL CENTER SOUTH
# 2               10006                     ELIZA COFFEE MEMORIAL HOSPITAL
# 3               10007                           MIZELL MEMORIAL HOSPITAL
# 4               10008                        CRENSHAW COMMUNITY HOSPITAL
# 5               10011                                  ST VINCENT'S EAST
# 6               10012                     DEKALB REGIONAL MEDICAL CENTER
# 7               10016                      SHELBY BAPTIST MEDICAL CENTER
# 8               10019                     HELEN KELLER MEMORIAL HOSPITAL
# 9               10021                                DALE MEDICAL CENTER
# 10              10022                            CHEROKEE MEDICAL CENTER
# 11              10023                       BAPTIST MEDICAL CENTER SOUTH
# ...

# %%
effective_care = pd.read_csv('Timely and Effective Care - Hospital.csv')
effective_care
# Out:
#        Provider ID                     Hospital Name                 Address  \
# 0           010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1           010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2           010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3           010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4           010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 5           010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 6           010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 7           010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 8           010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 9           010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 10          010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# ...

# %%
effective_care['Measure Name']
# Out:
# 0                                       Statin at Discharge
# 1                           Aspirin prescribed at discharge
# 2         Fibrinolytic Therapy Received Within 30 Minute...
# 3         Primary PCI Received Within 90 Minutes of Hosp...
# 4                                                       ED1
# 5                                                       ED2
# 6                               Emergency department volume
# 7                                    Discharge instructions
# 8                                Evaluation of LVS Function
# 9                                      ACEI or ARB for LVSD
# 10                               Immunization for influenza
# 11           Healthcare workers given influenza vaccination
# 12                              Median Time to Fibrinolysis
# 13                                                    OP 18
# 14        Fibrinolytic Therapy Received Within 30 Minute...
# 15                                  Door to diagnostic eval
# ...

# %%
effective_care.loc[effective_care['Measure Name'] == 'ED1']
# Out:
#        Provider ID                                      Hospital Name  \
# 4           010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 52          010005                      MARSHALL MEDICAL CENTER SOUTH
# 100         010006                     ELIZA COFFEE MEMORIAL HOSPITAL
# 148         010007                           MIZELL MEMORIAL HOSPITAL
# 196         010008                        CRENSHAW COMMUNITY HOSPITAL
# 244         010011                                  ST VINCENT'S EAST
# 292         010012                     DEKALB REGIONAL MEDICAL CENTER
# 340         010016                      SHELBY BAPTIST MEDICAL CENTER
# 388         010018                              CALLAHAN EYE HOSPITAL
# 436         010019                     HELEN KELLER MEMORIAL HOSPITAL
# 484         010021                                DALE MEDICAL CENTER
# 532         010022                            CHEROKEE MEDICAL CENTER
# ...

# %%
readmissions = pd.read_csv('Readmissions and Deaths - Hospital.csv')
readmissions
# Out:
#       Provider ID                             Hospital Name  \
# 0          010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 1          010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 2          010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 3          010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 4          010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 5          010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 6          010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 7          010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 8          010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 9          010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 10         010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 11         010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 12         010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 13         010001          SOUTHEAST ALABAMA MEDICAL CENTER
# 14         010005             MARSHALL MEDICAL CENTER SOUTH
# ...
